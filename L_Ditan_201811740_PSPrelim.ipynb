# %% [markdown]
# <a href="https://colab.research.google.com/github/luigiditan/DSP/blob/main/L_Ditan_201811740_PSPrelim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Luigi Seanwell B. Ditan
# #### 201811740
# ####Prelim Problem Set

# %% [markdown]
# #**2.1 Complex Algebra 1**
#
# Identify the set of complex numbers that satisfies the condition $z^* = z^{−1}$
#
# $$z = z^-1 $$
# $$z = \frac{1}{z} $$
# $$z ⋅ z = \frac{1}{z} \cdot z $$
# $$z^2 = 1 $$
# $$z^2 - 1 = 0 $$
# $$(z+1)(z-1)=0 $$
# $$(z+1)=0 $$
# $$(z-1)=0$$
#
# $$z = 1, z = -1$$

# %% [markdown]
# #**2.2 Complex Algebra 2**
#
# Simplify the function
#
# $$x[n]=\frac{e^{j\frac{\pi}{2}} + e^{-j\frac{\pi}{2}}}{2} - \frac{e^{j\theta n} - {e^{-j\theta n}}}{i}$$

# %% [markdown]
# $$x[n]=\frac{cos{\frac{\pi}{2}} + {jsin\frac{\pi}{2}}}{2} - \frac{e^{j\theta n} - {e^{-j\theta n}}}{i}$$
#
# $$x[n]=\frac{cos{(90)} + {j \cdot sin(90)}}{2} - \frac{e^{j\theta n} - {e^{-j\theta n}}}{i}$$
#
# $$x[n]=\frac{0 + {j \cdot 0}}{2} - \frac{e^{j\theta n} - {e^{-j\theta n}}}{i} \cdot \frac{-i}{-i}$$
#
# $$x[n]=\frac{0 + {j \cdot 0}}{2} - \frac{e^{j\theta n} - {e^{-j\theta n}}}{i} \cdot \frac{-i}{-i}$$
#
# $$x[n]=0 - {(e^{j\theta n} + {e^{-j\theta n})(-i)}}$$
#
# $$x[n]={(e^{j\theta n} + {e^{-j\theta n})(i)}}$$

# %% [markdown]
# #**2.3 Periodic Signals**
#
# Compute for the minimum period $P$ in the samples of the signal $e^{j(M/N)\pi n}$
#
# (a) $e^{j2 \pi n}$ = 1
#
# (b) $e^{j(\frac{1}{3})2 \pi n}$ = 3
#
# (c) $e^{j(\frac{56}{9})2 \pi n}$ = 9

# %% [markdown]
# #**2.4 Signal Operations 1**
#
# Compute the moving average of the signal y[n] from an input signal
#
# $$x[n]=\delta[n]+2\delta[n-1]+3\delta[n-2]$$
#
# Whereas y[n] is defined as
#
# $$\frac{x[n]+x[n-1]}{2}$$

# %% [markdown]
# $$x[n] = 1, 2, 3 \\
# x[n-1] = 0, 1, 2$$
#
# Substitute the values to the equation:
#
# $$\frac{x[n]+x[n-1]}{2}$$
#
#
# $$\frac{1+0}{2}, \frac{2+1}{2}, \frac{3+2}{2}$$
#
#
#
# $$y[n] = \frac{1}{2}, \frac{3}{2}, \frac{5}{2}$$

# %% [markdown]
# #**2.5 Signal Operations 2**
#
# Consider the following block diagram
#
# ![Screen Shot 2022-02-27 at 7.22.46 PM.png](data:image/png;base64,...)
#
# What is the equation representing the output response $y[n]$ ?
#
# $$y[n] = b(ax[n]+x[n-1])-(x[n-3]((cx[n])+(x[n-1])))$$

# %% [markdown]
# #**2.6 Signal Operations 3**
#
# If we represent finite-length signals as vectors in Euclidean space, many operations on signals can be encoded as a matrix-vector multiplication. Consider for example a circular shift in $C^3$: a delay by one (i.e. a right shift) transforms the signal $x = [x0 \ x1 \ x2]$ into $x' = [x2 \ x1 \ x0]^T$ and it can be described by the
#
#
# $$D = \begin{bmatrix}
# 0 & 0 & 1\\
# 1 & 0 & 0\\
# 0 & 1 & 0
# \end{bmatrix}$$
#
# so that $x'=Dx$
#
# Determine the matrix $F$ that implements the one-step-different operator in $C^3$ i.e. the operator that transforms a signal $x$ into
#
#
# $$\frac{1}{\sqrt{2}}[(x_0+0.5x_1-x_2) \ \ (x_1-2x_0+x_2) \ \ (x_2-x_1)]^T$$
#
#
# $$F = \begin{bmatrix}
# 1 & 0.5 & -1\\
# -2 & 1 & 1\\
# 0 & -1 & 1
# \end{bmatrix} \cdot \frac{1}{\sqrt{2}}$$
#
#
# $$F = \begin{bmatrix}
# 0.7 & 0.4 & -0.7\\
# -1.41 & 0.7 & 0.7\\
# 0 & -0.7 & 0.7
# \end{bmatrix}$$
